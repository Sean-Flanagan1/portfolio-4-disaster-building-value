# %%
# these are my SCRAPS


TO DO - Stats between US database and Trulia

# %% [markdown]
# https://www.zillow.com/research/data/
#
#     Zillow purchased Trulia Circa 2014 https://money.cnn.com/2014/07/28/real_estate/zillow-buys-trulia-for-3-5-billion/index.html
#
#     https://www.zillow.com/research/total-value-homes-31-8-trillion-17763/  Valuations of us real estate
#
#     https://www.trulia.com/real_estate/New_York-New_York/market-trends/ Trulia market trends

# %% [markdown]
# streeteasy is much more NYC real estate oriented
# https://streeteasy.com/blog/data-dashboard/ Streeteasy's offerings for historical data - it seems it's focused on big metro area rentals so their sales numbers are heavily varied, which lends to Zillow and Trulia seeming to be the safest bets for what we are doing.

# %% [markdown]
# https://www.reddit.com/r/datasets/comments/91mrch/zillow_data_for_past_house_prices_and_rental/ discussion
#     Most in discussion seem to agree it's a pain scraping Zillow for data, their data is their business and
#     they do not want to dispense it too freely, they point to the census site and I found this, which doesn't have pricing data but has other housing info
#
#     https://www.census.gov/data/datasets/2017/demo/nychvs/microdata.html Not sure how to navigate this, might not be as useful as I'd hoped

# %% [markdown]
# https://www.census.gov/programs-surveys/acs/data.html - American Community Survey Data, not really in line with metrics we are seeking so not using this.

# %% [markdown]
# https://archive.nytimes.com/www.nytimes.com/interactive/2012/11/17/nyregion/hurricane-sandy-map.html Interactive death map of Sandy

# %% [markdown]
# https://www.businessinsider.com/new-york-city-preparing-storms-2016-10 storm preparation

# %% [markdown]
# https://www.businessinsider.com/triangle-fire-worst-disasters-new-york-city-2011-3#13-the-ninth-avenue-derailment-1
#
#  Worst architechtural/infrastructure related disasters in NYC

# %% [markdown]
# <h2> Precursory look at market data, to examine effect of Hurrican Sandy</h2>
#
# https://www.investopedia.com/articles/personal-finance/111115/zillow-estimates-not-accurate-you-think.asp
#
# lends to the idea that, although not totally accurate due to data input flaws, hot markets like NYC and San Francisco and LA etc markets by virtue of so much data is relatively more accurate than rural spaces.
#
# https://streeteasy.com/blog/hurricane-sandy-nyc-five-years-later-city-builds-where-floods-hit-hardest/ this could be a way better source than Zillow?
#
# https://www.pbs.org/newshour/economy/making-sense/why-housing-values-in-new-yorks-flood-zones-have-stayed-down-after-hurricane-sandy
#
# October 29th 2012 was when Hurricane Sandy impacted NYC. https://www.zillow.com/new-york-ny-11235/home-values/  the chart below shows Hurricane Sandy did not impact Brighton Beach real estate as a whole too much, Coney Island's dip in real estate values after November signifies there may have been an impact https://www.zillow.com/new-york-ny-11224/home-values/
#
# Red Hook https://www.zillow.com/new-york-ny-11231/home-values/
#
#
# https://www.zillow.com/new-york-ny-11414/home-values/ It seems the lows for Howard Beach Coincidentally occurred anyway during Sandy, and nonetheless slowly climbed back up!!
#
# 11693 Rockaway Beach doesn't have enough data prior to 2015, 11697 is even more barren of data
#
# https://www.zillow.com/new-york-ny-10005/home-values/  Fidi has some indication of clear negative market growth post Sandy, taking home markets ~10 months to recover
#
# Sean rightfully points out the market growth rates should be compared to US, maybe the metropolitan region?

# %% [markdown]
# **WORLD IS SAFER THAN EVER in terms of geoconflicts** https://www.ijpr.org/post/world-actually-safer-ever-and-heres-data-prove#stream/0

# %% [markdown]
# <b>Supplemental totally optional lit to look at - Sandy Hit Poor The Hardest</b>
#
# https://www.crainsnewyork.com/article/20130306/REAL_ESTATE/130309915/sandy-hit-the-poor-hardest-in-new-york

# %% [markdown]
# ## location of the historical data chart in the home values section - <div class="zm-homevalues-chart market-overview-chart" data-chartname="market-overview-chart" id="yui_3_18_1_1_1555308121426_1590">
#
#
#
#
# <div class="chart-filters zsg-toolbar zsg-toolbar_responsive-sm" id="yui_3_18_1_1_1555308121426_3845">
#     <ul class="zsg-toolbar-left" id="yui_3_18_1_1_1555308121426_3844">
#         <li id="yui_3_18_1_1_1555308121426_3843">
#             <fieldset class="zsg-toolbar-form-fieldset zsg-form-fieldset" id="yui_3_18_1_1_1555308121426_3842"><div class="zsg-form-field zsg-toolbar-form-field" id="yui_3_18_1_1_1555308121426_3841">
#                     <select name="chart-metric" data-param="metricType" class="chart-metric-filter" id="yui_3_18_1_1_1555308121426_1611">
#                                 <option data-paramvalue="zhvi_plus_forecast" data-valuetype="dollars" data-precision="-2" data-segmenttypes="1,2,3,4,5,30" selected="selected">Zillow Home Value Index</option>
#                                 <option data-paramvalue="18" data-valuetype="dollars" data-precision="-2" data-segmenttypes="1,3">Median list price</option>
#                                 <option data-paramvalue="19" data-valuetype="dollars" data-precision="-2" data-segmenttypes="1,3">Median sale price</option>
#                     </select>
#                 </div>
#
#                 <div class="zsg-form-field zsg-toolbar-form-field" id="yui_3_18_1_1_1555308121426_3856">
#                     <select name="data-bucket" data-param="dataBucket" class="data-bucket-filter" id="yui_3_18_1_1_1555308121426_1626">
#                         <option data-paramvalue="1">All homes</option>
#                         <optgroup label="Number of bedrooms">
#                             <option data-paramvalue="30">Studio</option>
#                             <option data-paramvalue="31" disabled="disabled">1 bedroom</option>
#                             <option data-paramvalue="32" disabled="disabled">2 bedroom</option>
#                             <option data-paramvalue="33" disabled="disabled">3 bedroom</option>
#                             <option data-paramvalue="34" disabled="disabled">4 bedroom</option>
#                             <option data-paramvalue="35" disabled="disabled">5+ bedrooms</option>
#                         </optgroup>
#
#                         <optgroup label="Home type">
#                             <option data-paramvalue="2">Single family</option>
#                             <option data-paramvalue="3">Condo / coop</option>
#                             <option data-paramvalue="9" disabled="disabled">Duplex / triplex</option>
#                         </optgroup>
#
#                         <optgroup label="Price tier">
#                             <option data-paramvalue="4">Top tier</option>
#                             <option data-paramvalue="5">Middle tier</option>
#                             <option data-paramvalue="6" disabled="disabled">Bottom tier</option>
#                         </optgroup>
#                     </select>
#                 </div>
#             </fieldset>
#         </li>
#         <li class="time-range-filter" id="yui_3_18_1_1_1555308121426_1641">
#             <ul class="zsg-toolbar-tabs zsg-tabs">
#                 <li data-param="timeRange" data-paramvalue="1"><a>1-yr</a></li>
#                 <li data-param="timeRange" data-paramvalue="5"><a>5-yr</a></li>
#                 <li data-param="timeRange" data-paramvalue="0" class="zsg-tab_active"><a>Max</a></li>
#             </ul>
#         </li>
#     </ul>
# </div>
#     <div class="chart-container zsg-content-component loaded" data-regionname="11224" id="yui_3_18_1_1_1555308121426_1913">
#         <div class="hide-no-svg">
#             Your browser doesn't seem to support SVG, this chart cannot be displayed.
#         </div>
#         <div class="chart-legend" id="yui_3_18_1_1_1555308121426_1940">
#             <ul class="legend-entries" id="yui_3_18_1_1_1555308121426_1942">
#                 <li class="legend-value">Feb 2020</li>
#             <li class="legend-entry legend-entry-0">11224 $596K</li><li class="hide legend-entry legend-entry-1"></li><li class="hide legend-entry legend-entry-2"></li><li class="hide legend-entry legend-entry-3"></li><li class="hide legend-entry legend-entry-4"></li><li class="hide legend-entry legend-entry-5"></li><li class="hide legend-entry legend-entry-6"></li></ul>
#         </div>
#         <div class="error-msg hidden hide">Sorry, no data currently available for this metric.</div>
#     <svg class="chart" width="820" height="408.2251082251082" viewBox="0 0 693 345" preserveAspectRatio="xMinYMax" id="yui_3_18_1_1_1555308121426_3835"><g class="inner-svg" transform="translate(15,20)"><g class="forecast" transform="translate(570.27734375,0)"><line class="forescast-line" x1="-1" x2="-1" y1="-30" y2="300"></line><text class="label label-left" x="0" y="-10" height="300" transform="translate(-50, 0)">Current</text><text class="label label-right" x="5" y="-10">Forecast</text><rect class="forecast-bg" x="0" y="0" height="300" width="48.722625841682316"></rect></g><g class="x axis" transform="translate(0, 0)"><g class="tick" transform="translate(42.95188529387175,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2010</text></g><g class="tick" transform="translate(99.71135356575536,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2011</text></g><g class="tick" transform="translate(156.470821837639,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2012</text></g><g class="tick" transform="translate(213.3857955020483,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2013</text></g><g class="tick" transform="translate(270.1452637739319,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2014</text></g><g class="tick" transform="translate(326.90473204581554,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2015</text></g><g class="tick" transform="translate(383.66420031769917,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2016</text></g><g class="tick" transform="translate(440.5791739821085,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2017</text></g><g class="tick" transform="translate(497.33864225399213,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2018</text></g><g class="tick" transform="translate(554.0981105258757,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2019</text></g><g class="tick" transform="translate(610.8575787977593,0)" style="opacity: 1;"><line y2="300" x2="0"></line><text y="313" x="0" dy=".71em" style="text-anchor: middle;">2020</text></g><path class="domain" d="M0,300V0H620V300"></path></g><g class="y axis" transform="translate(0, 0)"><g class="tick" transform="translate(0,300)" style="opacity: 1;"><line x2="620" y2="0"></line><text x="630" y="0" dy=".32em" style="text-anchor: start;">$321K</text></g><g class="tick" transform="translate(0,200)" style="opacity: 1;"><line x2="620" y2="0"></line><text x="630" y="0" dy=".32em" style="text-anchor: start;">$421K</text></g><g class="tick" transform="translate(0,100)" style="opacity: 1;"><line x2="620" y2="0"></line><text x="630" y="0" dy=".32em" style="text-anchor: start;">$521K</text></g><g class="tick" transform="translate(0,0)" style="opacity: 1;"><line x2="620" y2="0"></line><text x="630" y="0" dy=".32em" style="text-anchor: start;">$621K</text></g><g class="tick" transform="translate(0,-100)" style="opacity: 1;"><line x2="620" y2="0"></line><text x="630" y="0" dy=".32em" style="text-anchor: start;">$721K</text></g><path class="domain" d="M6,0H0V300H6"></path></g><line class="scrubber hide" x2="0" y2="300" transform="translate(0)"></line><path class="line line-0" d="M0,262L4.6651617757712565,266L9.48582894406822,270L14.150990719839477,273L18.97165788813644,275L23.79232505643341,274L28.457486832204662,272L33.27815400050163,270L37.94331577627288,268L42.76398294456985,263L47.58465011286682,260L51.938801103586655,260L56.75946827188362,262L61.42463004765487,263L66.24529721595184,261L70.91045899172309,256L75.73112616002005,253L80.55179332831702,255L85.21695510408829,258L90.03762227238525,257L94.70278404815652,256L99.52345121645347,258L104.34411838475044,261L108.69826937547028,258L113.51893654376724,252L118.18409831953849,247L123.00476548783547,249L127.66992726360672,254L132.49059443190367,259L137.31126160020065,261L141.9764233759719,263L146.79709054426885,266L151.4622523200401,266L156.2829194883371,261L161.10358665663404,256L165.6132430398796,252L170.43391020817657,249L175.09907198394782,247L179.9197391522448,243L184.58490092801605,236L189.40556809631303,231L194.22623526460995,228L198.8913970403812,220L203.71206420867819,208L208.37722598444944,201L213.19789315274642,208L218.0185603210434,215L222.37271131176323,219L227.19337848006018,220L231.85854025583146,220L236.6792074241284,216L241.3443691998997,212L246.1650363681966,209L250.9857035364936,210L255.65086531226484,217L260.4715324805618,227L265.1366942563331,230L269.95736142463005,227L274.778028592927,224L279.13217958364686,225L283.9528467519438,227L288.61800852771506,230L293.438675696012,232L298.10383747178327,234L302.9245046400802,236L307.7451718083772,238L312.4103335841485,238L317.2310007524454,238L321.8961625282167,236L326.7168296965137,230L331.53749686481063,223L335.89164785553044,220L340.71231502382744,219L345.3774767995987,214L350.19814396789565,213L354.8633057436669,216L359.6839729119639,216L364.50464008026086,205L369.1698018560321,192L373.99046902432906,185L378.6556308001003,183L383.4762979683973,183L388.2969651366942,183L392.8066215199398,180L397.6272886882368,178L402.292450464008,178L407.1131176323049,176L411.77827940807623,172L416.59894657637324,170L421.41961374467013,167L426.0847755204414,166L430.9054426887384,165L435.57060446450964,164L440.3912716328066,160L445.21193880110354,158L449.56608979182346,157L454.38675696012035,153L459.05191873589166,148L463.87258590418855,146L468.5377476799598,141L473.3584148482568,136L478.17908201655376,131L482.844243792325,128L487.66491096062197,125L492.3300727363932,125L497.1507399046902,123L501.9714070729872,117L506.325558063707,110L511.146225232004,103L515.8113870077752,97L520.6320541760722,92L525.2972159518434,87L530.1178831201405,81L534.9385502884375,74L539.6037120642087,67L544.4243792325055,61L549.0895410082769,57L553.9102081765739,57L558.7308753448708,56L563.0850263355907,54L563.0850263355907,54L567.9056935038876,51L572.5708552796589,48L577.3915224479558,45L582.0566842237271,42L586.877351392024,40L591.698018560321,38L596.3631803360922,36L601.1838475043892,34L605.8490092801604,31L610.6696764484575,27L615.4903436167544,26L620,25" style="opacity: 1;"></path><path class="line line-1" style="opacity: 0;"></path><path class="line line-2" style="opacity: 0;"></path><path class="line line-3" style="opacity: 0;"></path><path class="line line-4" style="opacity: 0;"></path><path class="line line-5" style="opacity: 0;"></path><path class="line line-6" style="opacity: 0;"></path><circle class="dot dot-0" r="3.5" transform="translate(-1000,-1000)"></circle><circle class="dot dot-1" r="3.5" transform="translate(-1000,-1000)"></circle><circle class="dot dot-2" r="3.5" transform="translate(-1000,-1000)"></circle><circle class="dot dot-3" r="3.5" transform="translate(-1000,-1000)"></circle><circle class="dot dot-4" r="3.5" transform="translate(-1000,-1000)"></circle><circle class="dot dot-5" r="3.5" transform="translate(-1000,-1000)"></circle><circle class="dot dot-6" r="3.5" transform="translate(-1000,-1000)"></circle></g></svg></div>
#     <div class="chart-compare-filter" id="yui_3_18_1_1_1555308121426_1650">
#         <div class="zsg-g">
#             <div class="zsg-lg-1-2">
#                 <ul class="remove-btns"><li class="remove-btn remove-btn-0" data-param="regions" data-paramvalue="62035"><span class="remove-btn-txt">11224</span></li></ul>
#             </div>
#             <div class="zsg-lg-1-2">
#                 <form action="" class="zm-search-module zsg-form" id="yui_3_18_1_1_1555308121426_1881">
#                     <div class="yui3-skin-sam zsg-form-field" id="yui_3_18_1_1_1555308121426_1880">
#                         <input type="text" class="zm-search-input yui3-aclist-input" placeholder="Compare" id="market-overview-chart-compare-search-input" required="" aria-autocomplete="list" aria-expanded="false" aria-owns="yui_3_18_1_1_1555308121426_1793" autocomplete="off">
#                     <div id="yui_3_18_1_1_1555308121426_1667" class="yui3-widget yui3-aclist yui3-widget-positioned yui3-aclist-hidden" aria-hidden="true" style="width: 224px; left: 1567.62px; top: 1109.03px;"><div id="yui_3_18_1_1_1555308121426_1669" class="yui3-aclist-content"><ul class="yui3-aclist-list" id="yui_3_18_1_1_1555308121426_1679" role="listbox"></ul></div></div><div class="yui3-aclist-aria" aria-live="polite" role="status"></div><div id="yui_3_18_1_1_1555308121426_1781" class="yui3-widget yui3-aclist yui3-widget-positioned yui3-aclist-hidden" aria-hidden="true" style="width: 224px; left: 1567.62px; top: 1109.03px;"><div id="yui_3_18_1_1_1555308121426_1783" class="yui3-aclist-content"><ul class="yui3-aclist-list" id="yui_3_18_1_1_1555308121426_1793" role="listbox"></ul></div></div><div class="yui3-aclist-aria" aria-live="polite" role="status"></div></div>
#                     <input type="submit" value="Submit" class="zm-search-btn zsg-button_primary">
#                 </form>
#             </div>
#         </div>
#     </div>
#     <!-- <div class="chart-compare-filter">
#         <form action="" class="zm-search-module zsg-toolbar">
#             <ul class="zsg-toolbar-left">
#                 <li>
#                     <ul class="remove-btns">
#                     </ul>
#                 </li>
#             </ul>
#             <ul class="zsg-toolbar-right">
#                 <li class="yui3-skin-sam zsg-toolbar-form-field zsg-form-field">
#                     <input type="text" class="zm-search-input" placeholder="Compare" id="market-overview-chart-compare-search-input" />
#                 </li>
#                 <li>
#                     <button type="submit" class="zm-search-btn zsg-toolbar-button zsg-button_primary">Submit</button>
#                 </li>
#             </ul>
#         </form>
#     </div> -->
#     <div class="zm-region-comparison yui3-toggle yui3-toggle-content-minimized" id="yui_3_18_1_1_1555308121426_97">
#     <a href="#" class="toggle-content-link" data-minimize="Hide Data Table" data-maximize="View Data Table">View Data Table</a>
#     <div class="toggle-content">
#         <div class="region-comparison-table">
#             <div class="region-type-filter-btns">
#                 <ul class="region-type-filter zsg-tabs zsg-tabs_lg">
#
#
#                             <li data-param="comparisonTable.regionTypeId" data-paramvalue="14" class="zsg-tab_active">
#                                 <a>Metros</a>
#                             </li>
#
#
#
#                             <li data-param="comparisonTable.regionTypeId" data-paramvalue="4">
#                                 <a>Counties</a>
#                             </li>
#
#
#
#                             <li data-param="comparisonTable.regionTypeId" data-paramvalue="6">
#                                 <a>Cities</a>
#                             </li>
#
#
#
#                             <li data-param="comparisonTable.regionTypeId" data-paramvalue="7">
#                                 <a>Zip Codes</a>
#                             </li>
#
#
#
#                             <li data-param="comparisonTable.regionTypeId" data-paramvalue="8">
#                                 <a>Neighborhoods</a>
#                             </li>
#
#
#                 </ul>
#             </div>
#             <div class="region-comparison-table-contents hide">
#             </div>
#             <div class="region-comparison-table-warning hide">
#                 <p class="zss-no-data">We are currently unable to retrieve data matching your current criteria.</p>
#             </div>
#             <div class="region-comparison-table-loading loading-message">
#                 <span class="loading-indicator"></span>
#                 <p>loading</p>
#             </div>
#             <div class="data-download-links sub-module-actions">
#                 <a href="/market-report/04-19/62035/new-york-ny-11224.xls" title="Market Report Link" class="market-report-link" rel="nofollow">Download Full Data</a>
#                 |
#                 <a href="/market-report/time-series/62035/new-york-ny-11224.xls" title="Time Series Excel" class="time-series-link" rel="nofollow">Download Chart Data</a>
#             </div>
#         </div>
#     </div>
# </div>
# </div>

# %%
import quandl
import pandas as pd

# %%
#what is quandl_key here?

def get_key(path = './quandl_key.conf'):
    with open(path, 'r') as f:
        key = f.readline()

    return key


def historical_data(zipcode):
    key = get_key()
    indicator = 'ZILLOW/Z' + str(zipcode) + '_MLPAH'
    quandl.ApiConfig.api_key = key
    try:
        df = pd.DataFrame(quandl.get(indicator))
    except:
        df = ''
    return df

# %%
historical_data(11233)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2fb332179ff7> in <module>
# ----> 1 historical_data(11233)
#
# <ipython-input-2-75b6614e9d0a> in historical_data(zipcode)
#       9
#      10 def historical_data(zipcode):
# ---> 11     key = get_key()
#      12     indicator = 'ZILLOW/Z' + str(zipcode) + '_MLPAH'
#      13     quandl.ApiConfig.api_key = key
#
# <ipython-input-2-75b6614e9d0a> in get_key(path)
#       2
#       3 def get_key(path = './quandl_key.conf'):
# ----> 4     with open(path, 'r') as f:
#       5         key = f.readline()
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: './quandl_key.conf'

# %%
import pandas as pd 
import numpy as np

# %%
pd.read_csv('Zip_Zhvi_Summary_AllHomes.csv', encoding='latin-1' ) 

# proper formatting tip from https://stackoverflow.com/questions/5552555/unicodedecodeerror-invalid-continuation-byte 
# downloaded from https://www.zillow.com/research/data/
# Out:
#              Date  RegionID  RegionName State  \
# 0      2019-02-28     61639       10025    NY
# 1      2019-02-28     84654       60657    IL
# 2      2019-02-28     61637       10023    NY
# 3      2019-02-28     91982       77494    TX
# 4      2019-02-28     84616       60614    IL
# 5      2019-02-28     93144       79936    TX
# 6      2019-02-28     91940       77449    TX
# 7      2019-02-28     91733       77084    TX
# 8      2019-02-28     61616       10002    NY
# 9      2019-02-28     61807       10467    NY
# 10     2019-02-28     84640       60640    IL
# 11     2019-02-28     62037       11226    NY
# 12     2019-02-28     97564       94109    CA
# 13     2019-02-28     61630       10016    NY
# 14     2019-02-28     74101       37013    TN
# 15     2019-02-28     92593       78660    TX
# 16     2019-02-28     71831       32162    FL
# 17     2019-02-28     62087       11375    NY
# 18     2019-02-28     62045       11235    NY
# ...

# %%
def zip_authenticator(ziplist):
    for z in ziplist:
        if len(str(z)) != 5:
            print("Zipcodes contain 5 digits, please make sure your inputs are valid.")
        elif z != int or float:
            print("zipcodes consist only of 5 numeric digits as an integer or float, please only input numbers!")
        else: print("you're all good!")

# %%
ziplist = 11111, 10942, 11092

# %%
zip_authenticator(ziplist)
# Out:
# zipcodes consist only of 5 numeric digits as an integer or float, please only input numbers!
# zipcodes consist only of 5 numeric digits as an integer or float, please only input numbers!
# zipcodes consist only of 5 numeric digits as an integer or float, please only input numbers!

# %%
ziplist = list
#ziplist = []
#zipcode_list = zip_feeder(ziplist)
def zip_feeder(ziplist):
    ziplist = []
    for z in ziplist:    
        numbers = int(input())
        ziplist.append(z)
        
    return ziplist
    
print(ziplist)
# Out:
# [6543574, 346526547, 6345264, 436]

# %%
def zip_feeder(ziplist):
    #zlist = list
    zlist = []
    number = int(input())
    print("press 1 then continue ")
    for z in range(0,5):  
#         if len(str(z)) != 5:
#             print("Zipcodes contain 5 digits, please make sure your inputs are valid.")
#             pass
#         elif z != int or float:
#             print("zipcodes consist only of 5 numeric digits as an integer or float, please only input numbers!")
#             pass
#         else: print("you're all good!")
        #print("press 1 then continue ")
        numbers = int(input())
        list.append(numbers)
        zlist = list
        print(zlist)

# %%
zip_feeder(ziplist)
# Out:
# 3
# press 1 then continue
# 3
# [6543574, 346526547, 6345264, 436, 65432, 756432, 76543, 5764, 65432, 76543, 765432, 76543, 6543, 65432, 765432, 65432, 6543, 76543, 76543, 76543, 11233, 222222, 1233, 5432, 4532, 5432, 5423, 432, 5434, 43444, 45363, 64363, 11111, 11111, 11111, 11111, 11111, 543, 54325, 75646745, 7654637, 7654573745, 764753745754754, 1, 1, 1, 1, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 1, 54632, 65432, 75643, 756432, 6675432, 65432, 65432, 65432, 65432, 3, 3, 3, 3, 3]
# 3
# [6543574, 346526547, 6345264, 436, 65432, 756432, 76543, 5764, 65432, 76543, 765432, 76543, 6543, 65432, 765432, 65432, 6543, 76543, 76543, 76543, 11233, 222222, 1233, 5432, 4532, 5432, 5423, 432, 5434, 43444, 45363, 64363, 11111, 11111, 11111, 11111, 11111, 543, 54325, 75646745, 7654637, 7654573745, 764753745754754, 1, 1, 1, 1, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 1, 54632, 65432, 75643, 756432, 6675432, 65432, 65432, 65432, 65432, 3, 3, 3, 3, 3, 3]
# 3
# ...

# %%
ziplist
# Out:
# []

# %%
 ziplist = zlist

# %%
### list =[]
number = int(input())
for i in range(1,5):    
    numbers = int(input())
    list.append(numbers)
    ziplist = list
print(ziplist)

# %%
ziplist
# Out:
# [6543574,
#  346526547,
#  6345264,
#  436,
#  65432,
#  756432,
#  76543,
#  5764,
#  65432,
#  76543,
#  765432,
#  76543,
#  6543,
#  65432,
#  765432,
#  65432,
#  6543,
#  76543,
#  76543,
#  76543,
#  11233,
#  222222,
#  1233,
#  5432,
#  4532,
#  5432,
#  5423,
#  432,
#  5434,
#  43444,
#  45363,
#  64363,
#  11111,
#  11111,
#  11111,
#  11111,
#  11111,
#  543,
#  54325,
#  75646745,
#  7654637,
#  7654573745,
#  764753745754754,
#  1,
#  1,
#  1,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3]

# %%
ziplist
# Out:
# [65432, 65432, 65432, 75432]

# %%
list =[]
number = int(input())
for i in range(0,5):    
    numbers = int(input())
    list.append(numbers)
    ziplist = list
print(ziplist)
# Out:
# 4532
# 643524
# 756432
# 75643
# 6543
# 26453
# [643524, 756432, 75643, 6543, 26453]

# %%
ziplist
# Out:
# [643524, 756432, 75643, 6543, 26453]
